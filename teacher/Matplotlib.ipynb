# %% [markdown]
# ###  Matplotlib
# * 그래프나 그림을 그릴 수 있는 플라팅(plotting) 라이브러리
# * 파이썬에서 제공하는 함수들을 사용하면 매트랩(Matlab)처럼
# 다룰 수 있으며 제공되는 기능이나 문법(syntax)도 비슷함
# * 파이썬에서 Matplot의 기능을 인터렉티브하게 사용할 수 있음
# * Pyplot 모듈을 사용하여 데이터를 시각적으로 표현
# * Matplot과 인터페이스 역할을 하는 것으로 상태 머신(state
# machine)이라고도 함

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
x = range(1,11)

plt.plot(x)
plt.show()

# %%
y = [10,14,17,19,20]
x = [2,4,6,7,8]

# %%
plt.plot(x, y)

# %% [markdown]
# ##### 라벨(label)입력
# * xlabel() : x축 라벨 입력
# * ylabel() : y축 라벨 입력

# %%
y = [10,14,17,19,20]
x = [2,4,6,7,8]
plt.plot(x, y)
plt.xlabel("study")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# ##### 그래프 추가

# %%
x = ["mon","tue","wed","Thur","Fri"]
y_1 = [10,14,17,19,20]
y_2 = [11,20,13,19,15]
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.xlabel("study")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# ##### 레전드(legend)붙이기

# %% [markdown]
# 위치 지정 문자열과 코드는 아래의 표를 참고하세요.
#
# | Location String | Location Code | 설명                                        |
# | :-------------- | :------------ | :------------------------------------------ |
# | ‘best’          | 0             | 그래프의 최적의 위치에 표시합니다. (디폴트) |
# | ‘upper right’   | 1             | 그래프의 오른쪽 위에 표시합니다.            |
# | ‘upper left’    | 2             | 그래프의 왼쪽 위에 표시합니다.              |
# | ‘lower left’    | 3             | 그래프의 왼쪽 아래에 표시합니다.            |
# | ‘lower right’   | 4             | 그래프의 오른쪽 아래에 표시합니다.          |
# | ‘right’         | 5             | 그래프의 오른쪽에 표시합니다.               |
# | ‘center left’   | 6             | 그래프의 왼쪽 가운데에 표시합니다.          |
# | ‘center right’  | 7             | 그래프의 오른쪽 가운데에 표시합니다.        |
# | ‘lower center’  | 8             | 그래프의 가운데 아래에 표시합니다.          |
# | ‘upper center’  | 9             | 그래프의 가운데 위에 표시합니다.            |
# | ‘center’        | 10            | 그래프의 가운데에 표시합니다.               |

# %%
x = ["mon","tue","wed","Thur","Fri"]
y_1 = [10,14,17,19,20]
y_2 = [11,20,13,19,15]
plt.plot(x, y_1 , label="math")
plt.plot(x, y_2 ,label="english" )
plt.xlabel("study")
plt.ylabel("score")
plt.legend(loc="upper left" , ncol=2)

# %% [markdown]
# ##### 제목 넣기

# %%
x = ["mon","tue","wed","Thur","Fri"]
y_1 = [10,14,17,19,20]
y_2 = [11,20,13,19,15]
plt.plot(x, y_1 , label="math")
plt.plot(x, y_2 ,label="english" )
plt.xlabel("study")
plt.ylabel("score")
plt.legend(loc="upper left" , ncol=2)
plt.title("score per study")
# Out:
# Text(0.5, 1.0, 'score per study')

# %% [markdown]
# ##### 'bo' 옵션주기

# %%
x = ["mon","tue","wed","Thur","Fri"]
y_1 = [10,14,17,19,20]
y_2 = [11,20,13,19,15]
plt.plot(x, y_1 ,'bo', label="math")

# %%
x = ["mon","tue","wed","Thur","Fri"]
y_1 = [10,14,17,19,20]
y_2 = [11,20,13,19,15]
plt.plot(x, y_1 ,'^r:', label="math")

# %% [markdown]
# ##### pdf로 저장하기

# %%
x = ["mon","tue","wed","Thur","Fri"]
y_1 = [10,14,17,19,20]
y_2 = [11,20,13,19,15]
plt.plot(x, y_1 , label="math")
plt.plot(x, y_2 ,label="english" )
plt.xlabel("study")
plt.ylabel("score")
plt.legend(loc="upper left" , ncol=2)
plt.title("score per study")
plt.savefig("mplot.pdf")

# %%
x = np.random.standard_normal(size=100)
plt.hist(x)
# Out:
# (array([ 4.,  2., 11., 15., 21., 14., 15.,  7.,  6.,  5.]),
#  array([-2.44006926, -1.96264534, -1.48522142, -1.0077975 , -0.53037357,
#         -0.05294965,  0.42447427,  0.90189819,  1.37932212,  1.85674604,
#          2.33416996]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ##### 산점도 그리기

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
shape = np.pi*(np.random.rand(30)*20)**2
plt.scatter(x ,y , c=colors, s= shape, marker="o", alpha=0.7)
plt.show()
