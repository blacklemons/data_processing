# %% [markdown]
# ### Matplotlib 기본사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([2, 3, 5, 10])
plt.show()

# %% [markdown]
# #### x,y 값 입력

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.show()

# %% [markdown]
# #### 레이블이 있는 데이터 사용

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.show()

# %% [markdown]
# ### 레이블 설정
# #### 기본 설정
#  - xlable() 가로 축 설정
#  - ylable() 세로 축 설정

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# #### 여백지정

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15)
plt.ylabel('Y-Axis', labelpad=20)
plt.show()

# %% [markdown]
# #### 폰트 설정

# %%
import matplotlib.pyplot as plt

font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %% [markdown]
# 주요한 속성에 대한 설명과 옵션
#
# | Property | Description     | Option                                                       |
# | :------- | :-------------- | :----------------------------------------------------------- |
# | alpha    | 텍스트의 투명도 | 0.0 ~ 1.0 (float)                                            |
# | color    | 텍스트의 색상   | Any Matplotlib color                                         |
# | family   | 텍스트의 글꼴   | [FONTNAME \| ‘serif’ \| ‘sans-serif’ \| ‘cursive’ \| ‘fantasy’ \| ‘monospace’ ] |
# | rotation | 텍스트의 회전각 | [angle in degrees \| ‘vertical’ \| ‘horizontal’ ]            |
# | size     | 텍스트의 크기   | [size in points \| ‘xx-small’ \| ‘x-small’ \| ‘small’ \| ‘medium’ \| ‘large’ \| ‘x-large’ \| ‘xx-large’ ] |
# | weight   | 텍스트의 굵기   | [a numeric value in range 0-1000 \| ‘ultralight’ \| ‘light’ \| ‘normal’ \| ‘regular’ \| ‘book’ \| ‘medium’ \| ‘roman’ \| ‘semibold’ \| ‘demibold’ \| ‘demi’ \| ‘bold’ \| ‘heavy’ \| ‘extra bold’ \| ‘black’ ] |

# %% [markdown]
# #### 위치 지정

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', loc='right')
plt.ylabel('Y-Axis', loc='top')
plt.show()

# %% [markdown]
# ### 범례 표시

# %% [markdown]
# #### 기본사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %% [markdown]
# #### 위치 지정
# legend() 함수의 loc 파라미터를 이용하여 범례 표시 위치 설정

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc=(0.0, 0.0))
# plt.legend(loc=(0.5, 0.5))
plt.legend(loc=(1.0, 1.0))

plt.show()

# %% [markdown]
# 위치 지정 문자열과 코드
#
# | Location String | Location Code | 설명                                        |
# | :-------------- | :------------ | :------------------------------------------ |
# | ‘best’          | 0             | 그래프의 최적의 위치에 표시합니다. (디폴트) |
# | ‘upper right’   | 1             | 그래프의 오른쪽 위에 표시합니다.            |
# | ‘upper left’    | 2             | 그래프의 왼쪽 위에 표시합니다.              |
# | ‘lower left’    | 3             | 그래프의 왼쪽 아래에 표시합니다.            |
# | ‘lower right’   | 4             | 그래프의 오른쪽 아래에 표시합니다.          |
# | ‘right’         | 5             | 그래프의 오른쪽에 표시합니다.               |
# | ‘center left’   | 6             | 그래프의 왼쪽 가운데에 표시합니다.          |
# | ‘center right’  | 7             | 그래프의 오른쪽 가운데에 표시합니다.        |
# | ‘lower center’  | 8             | 그래프의 가운데 아래에 표시합니다.          |
# | ‘upper center’  | 9             | 그래프의 가운데 위에 표시합니다.            |
# | ‘center’        | 10            | 그래프의 가운데에 표시합니다.               |

# %% [markdown]
# #### 열 개수 지정

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=2)    # ncol = 2

plt.show()

# %% [markdown]
# #### 폰트 크기 지정

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

plt.show()

# %% [markdown]
# #### 범례 테두리 꾸미기
# frameon : 범례 텍스트 상자의 테두리를 표시ㅍ여부
#
# frameon=False : 테두리가 표시 거부
#
# shadow : 텍스트 상자에 그림자를 표시

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)

plt.show()

# %% [markdown]
# ### pdf로 저장

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.savefig('mplot.pdf')

# %%
x=np.random.standard_normal(size=100)
plt.hist()
# Out:
# (array([ 4.,  4.,  8., 19., 16., 20., 18.,  7.,  2.,  2.]),
#  array([-2.3424072 , -1.86368167, -1.38495613, -0.90623059, -0.42750506,
#          0.05122048,  0.52994601,  1.00867155,  1.48739708,  1.96612262,
#          2.44484815]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 산점도 그리기

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
shape = np.pi*(np.random.rand(30)*20)**2

plt.scatter(x,y,c=colors,s=shape,marker='o',alpha=0.7)
plt.show()

# %% [markdown]
# #### 기본 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# #### 색상과 크기 지정

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1], [1], 'o', markersize=20, c='#FF5733')
plt.scatter([2], [1], s=20**2, c='#33FFCE')

plt.text(0.5, 1.05, 'plot(markersize=20)', fontdict={'size': 14})
plt.text(1.6, 1.05, 'scatter(s=20**2)', fontdict={'size': 14})
plt.axis([0.4, 2.6, 0.8, 1.2])
plt.show()

# %% [markdown]
# #### 투명도와 컬러맵 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Spectral')
plt.colorbar()
plt.show()
